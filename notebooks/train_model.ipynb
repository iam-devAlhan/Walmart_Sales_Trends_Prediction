# %%
# Machine Learning Work here
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import joblib # THis module is for dumping model into pkl form
# Example is joblib.dump(model, "model_something.pkl")
# Remaining here choose your algorithm
